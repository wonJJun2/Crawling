# %%
import requests
import json

key = 'WFYss6QSGZq1BFfei9UhgjkiocywtcCAXeiwiDeqxCWBkKKWstHkz%2BFcAPQC8KEh9HkQ363a0b%2BtV2qaJu%2FmLQ%3D%3D'
# decode_key = requests.utils.unquote(key)

response = requests.get('http://apis.data.go.kr/1470000/FoodNtrIrdntInfoService\
# ?serviceKey={}\
&numOfRows=10\
&pageNo=1\
&dataType=JSON\
&CURRENT_DATE=2021042001\
&HOUR=24\
&COURSE_ID=2'.format(key))

print(response)
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE"},"body":{"dataType":"JSON","items":{"item":[{"tm":"2021-04-22 00:00","thema":"캠핑/스포츠","courseId":"2","courseAreaId":"4300000000","courseAreaName":"충청북도","courseName":"천년의 비밀을 지닌 고찰에서 캠핑을 하다","spotAreaId":203,"spotAreaName":"영동","spotName":"(영동)송호국민관광지캠핑장","th3":13,"wd":248,"ws":0,"sky":3,"rhm":75,"pop":20},{"tm":"2021-04-22 00:00","thema":"종교/역사/전통","courseId":"2","courseAreaId":"4300000000","courseAreaName":"충청북도","courseName":"천년의 비밀을 지닌 고찰에서 캠핑을 하다","spotAreaId":203,"spotAreaName":"영동","spotName":"(영동)송호국민관광지캠핑장","th3":13,"wd":248,"ws":0,"sky":3,"rhm":75,"pop":20},{"tm":"2021-04-22 00:00","thema":"종교/역사/전통","courseId":"2","courseAreaId":"4300000000","courseAreaName":"충청북도","courseName":"천년의 비밀을 지닌 고찰에서 캠핑을 하다","spotAreaId":201,"spotAreaName":"영동","spotName":"(영동)영국사","th3":13,"wd":225,"ws":0,"sky":3,"rhm":70,"pop":20},{"tm":"2021-04-22 00:00","thema":"캠핑/스포츠","courseId":"2","courseAreaId":"4300000000","courseAr
# ...

# %%
data=json.loads(response.text)
data
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_SERVICE'},
#   'body': {'dataType': 'JSON',
#    'items': {'item': [{'tm': '2021-04-22 00:00',
#       'thema': '캠핑/스포츠',
#       'courseId': '2',
#       'courseAreaId': '4300000000',
#       'courseAreaName': '충청북도',
#       'courseName': '천년의 비밀을 지닌 고찰에서 캠핑을 하다',
#       'spotAreaId': 203,
#       'spotAreaName': '영동',
#       'spotName': '(영동)송호국민관광지캠핑장',
#       'th3': 13,
#       'wd': 248,
#       'ws': 0,
#       'sky': 3,
#       'rhm': 75,
#       'pop': 20},
#      {'tm': '2021-04-22 00:00',
#       'thema': '종교/역사/전통',
#       'courseId': '2',
#       'courseAreaId': '4300000000',
#       'courseAreaName': '충청북도',
#       'courseName': '천년의 비밀을 지닌 고찰에서 캠핑을 하다',
#       'spotAreaId': 203,
#       'spotAreaName': '영동',
#       'spotName': '(영동)송호국민관광지캠핑장',
#       'th3': 13,
#       'wd': 248,
#       'ws': 0,
#       'sky': 3,
#       'rhm': 75,
#       'pop': 20},
#      {'tm': '2021-04-22 00:00',
# ...

# %%
a = data['response']['body']['items']['item']
print(len(a))
a
# Out:
# 10
# [{'tm': '2021-04-22 00:00',
#   'thema': '캠핑/스포츠',
#   'courseId': '2',
#   'courseAreaId': '4300000000',
#   'courseAreaName': '충청북도',
#   'courseName': '천년의 비밀을 지닌 고찰에서 캠핑을 하다',
#   'spotAreaId': 203,
#   'spotAreaName': '영동',
#   'spotName': '(영동)송호국민관광지캠핑장',
#   'th3': 13,
#   'wd': 248,
#   'ws': 0,
#   'sky': 3,
#   'rhm': 75,
#   'pop': 20},
#  {'tm': '2021-04-22 00:00',
#   'thema': '종교/역사/전통',
#   'courseId': '2',
#   'courseAreaId': '4300000000',
#   'courseAreaName': '충청북도',
#   'courseName': '천년의 비밀을 지닌 고찰에서 캠핑을 하다',
#   'spotAreaId': 203,
#   'spotAreaName': '영동',
#   'spotName': '(영동)송호국민관광지캠핑장',
#   'th3': 13,
#   'wd': 248,
#   'ws': 0,
#   'sky': 3,
#   'rhm': 75,
#   'pop': 20},
#  {'tm': '2021-04-22 00:00',
#   'thema': '종교/역사/전통',
#   'courseId': '2',
#   'courseAreaId': '4300000000',
#   'courseAreaName': '충청북도',
#   'courseName': '천년의 비밀을 지닌 고찰에서 캠핑을 하다',
#   'spotAreaId': 201,
#   'spotAreaName': '영동',
#   'spotName': '(영동)영국사',
#   'th3': 13,
# ...
